# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint

from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz

# %%
bank_data= pd.read_csv("bank-marketing.csv")

# %%
bank_data.head()
# Out:
#    index  age        job  marital    education  default housing loan  \
# 0      0   56  housemaid  married     basic.4y       no      no   no
# 1      1   57   services  married  high.school  unknown      no   no
# 2      2   37   services  married  high.school       no     yes   no
# 3      3   40     admin.  married     basic.6y       no      no   no
# 4      4   56   services  married  high.school       no      no  yes
#
#      contact month  ... campaign  pdays  previous     poutcome  emp.var.rate  \
# 0  telephone   may  ...        1    999         0  nonexistent           1.1
# 1  telephone   may  ...        1    999         0  nonexistent           1.1
# 2  telephone   may  ...        1    999         0  nonexistent           1.1
# 3  telephone   may  ...        1    999         0  nonexistent           1.1
# 4  telephone   may  ...        1    999         0  nonexistent           1.1
#
#   cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0         93.994          -36.4      4.857         5191  no
# 1         93.994          -36.4      4.857         5191  no
# 2         93.994          -36.4      4.857         5191  no
# 3         93.994          -36.4      4.857         5191  no
# 4         93.994          -36.4      4.857         5191  no
#
# [5 rows x 22 columns]

# %%
bank_data['default'] = bank_data['default'].map({'no':0,'yes':1,'unknown':0})
bank_data['y'] = bank_data['y'].map({'no':0,'yes':1,'unknown':0})

# %%
bank_data
# Out:
#     index  age          job   marital            education  default housing  \
# 0       0   56    housemaid   married             basic.4y        0      no
# 1       1   57     services   married          high.school        0      no
# 2       2   37     services   married          high.school        0     yes
# 3       3   40       admin.   married             basic.6y        0      no
# 4       4   56     services   married          high.school        0      no
# ..    ...  ...          ...       ...                  ...      ...     ...
# 95     95   45     services   married  professional.course        0     yes
# 96     96   42   management   married    university.degree        0      no
# 97     97   53       admin.  divorced    university.degree        0      no
# 98     98   37   technician    single  professional.course        0      no
# 99     99   44  blue-collar   married             basic.6y        0      no
#
#    loan    contact month  ... campaign  pdays  previous     poutcome  \
# 0    no  telephone   may  ...        1    999         0  nonexistent
# 1    no  telephone   may  ...        1    999         0  nonexistent
# 2    no  telephone   may  ...        1    999         0  nonexistent
# 3    no  telephone   may  ...        1    999         0  nonexistent
# 4   yes  telephone   may  ...        1    999         0  nonexistent
# ..  ...        ...   ...  ...      ...    ...       ...          ...
# 95   no  telephone   may  ...        1    999         0  nonexistent
# 96   no  telephone   may  ...        1    999         0  nonexistent
# 97   no  telephone   may  ...        1    999         0  nonexistent
# 98   no  telephone   may  ...        1    999         0  nonexistent
# 99   no  telephone   may  ...        1    999         0  nonexistent
#
#     emp.var.rate cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# 0            1.1         93.994          -36.4      4.857         5191  0
# 1            1.1         93.994          -36.4      4.857         5191  0
# 2            1.1         93.994          -36.4      4.857         5191  0
# 3            1.1         93.994          -36.4      4.857         5191  0
# 4            1.1         93.994          -36.4      4.857         5191  0
# ..           ...            ...            ...        ...          ... ..
# 95           1.1         93.994          -36.4      4.857         5191  0
# 96           1.1         93.994          -36.4      4.857         5191  0
# 97           1.1         93.994          -36.4      4.857         5191  0
# 98           1.1         93.994          -36.4      4.857         5191  0
# 99           1.1         93.994          -36.4      4.857         5191  0
#
# [100 rows x 22 columns]

# %%
feature_cols = ['age', 'default', 'cons.price.idx', 'cons.conf.idx']
X = bank_data[feature_cols]
y = bank_data['y']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
bank_data
# Out:
#     index  age          job   marital            education  default housing  \
# 0       0   56    housemaid   married             basic.4y        0      no
# 1       1   57     services   married          high.school        0      no
# 2       2   37     services   married          high.school        0     yes
# 3       3   40       admin.   married             basic.6y        0      no
# 4       4   56     services   married          high.school        0      no
# ..    ...  ...          ...       ...                  ...      ...     ...
# 95     95   45     services   married  professional.course        0     yes
# 96     96   42   management   married    university.degree        0      no
# 97     97   53       admin.  divorced    university.degree        0      no
# 98     98   37   technician    single  professional.course        0      no
# 99     99   44  blue-collar   married             basic.6y        0      no
#
#    loan    contact month  ... campaign  pdays  previous     poutcome  \
# 0    no  telephone   may  ...        1    999         0  nonexistent
# 1    no  telephone   may  ...        1    999         0  nonexistent
# 2    no  telephone   may  ...        1    999         0  nonexistent
# 3    no  telephone   may  ...        1    999         0  nonexistent
# 4   yes  telephone   may  ...        1    999         0  nonexistent
# ..  ...        ...   ...  ...      ...    ...       ...          ...
# 95   no  telephone   may  ...        1    999         0  nonexistent
# 96   no  telephone   may  ...        1    999         0  nonexistent
# 97   no  telephone   may  ...        1    999         0  nonexistent
# 98   no  telephone   may  ...        1    999         0  nonexistent
# 99   no  telephone   may  ...        1    999         0  nonexistent
#
#     emp.var.rate cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# 0            1.1         93.994          -36.4      4.857         5191  0
# 1            1.1         93.994          -36.4      4.857         5191  0
# 2            1.1         93.994          -36.4      4.857         5191  0
# 3            1.1         93.994          -36.4      4.857         5191  0
# 4            1.1         93.994          -36.4      4.857         5191  0
# ..           ...            ...            ...        ...          ... ..
# 95           1.1         93.994          -36.4      4.857         5191  0
# 96           1.1         93.994          -36.4      4.857         5191  0
# 97           1.1         93.994          -36.4      4.857         5191  0
# 98           1.1         93.994          -36.4      4.857         5191  0
# 99           1.1         93.994          -36.4      4.857         5191  0
#
# [100 rows x 22 columns]

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(X_test)

# %%
for i in range(3):
    tree = rf.estimators_[i]
    dot_data = export_graphviz(tree,
                               feature_names=X_train.columns,  
                               filled=True,  
                               max_depth=2, 
                               impurity=False, 
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
    precision_score,
    recall_score,
    classification_report,
)



accuracy = accuracy_score(y_pred, y_test,)
f1 = f1_score(y_pred, y_test, average="weighted")
precision = precision_score(y_pred, y_test, average="weighted", zero_division=0)
recall = recall_score(y_pred, y_test, average="weighted", zero_division=0)

print("Accuracy:", accuracy)
print("F1 Score:", f1)
print("Precision:", precision)
print("Recall:", recall)
# Out:
# Accuracy: 0.95
# F1 Score: 0.9743589743589742
# Precision: 1.0
# Recall: 0.95

# %%
labels = ["", "Not fully Paid"]
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot();
